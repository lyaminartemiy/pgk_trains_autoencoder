# %% [markdown]
# ## Train Dataset Testing

# %%
cd ..
# Out:
# C:\Users\Artemiy\Desktop\Data Science\Проекты\pgk_trains_generator

# %%
from src.dataset.create_dataset import TrainsDataset
from src.dataset.main_dataset import main_dataset

from matplotlib import pyplot as plt
# %matplotlib inline

import numpy as np
from PIL import Image
from IPython.display import display


train_dataset = main_dataset()

for _ in range(1, 10, 2):
    img = train_dataset[_].numpy()
    img = np.transpose(img, (1, 2, 0))
    img = Image.fromarray((img * 255).astype(np.uint8))
    
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x258235461C0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x258235461C0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x25823B95F40>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x25823BBFF10>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x258235461C0>
